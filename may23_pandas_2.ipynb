# %% [markdown]
# <a href="https://colab.research.google.com/github/adityajain2407/DAV-1-may23/blob/main/may23_pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("mckinsey.csv")

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head(10)
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106
# 5  Afghanistan  1977    14880372      Asia    38.438  786.113360
# 6  Afghanistan  1982    12881816      Asia    39.854  978.011439
# 7  Afghanistan  1987    13867957      Asia    40.822  852.395945
# 8  Afghanistan  1992    16317921      Asia    41.674  649.341395
# 9  Afghanistan  1997    22227415      Asia    41.763  635.341351

# %%
df["country"].value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
#renaming a column

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.rename({
    "population" : "Population",
    "country" : "Country"
})
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename({
    "population" : "Population",
    "country" : "Country"
},
          axis = 1)
# Out:
#           Country  year  Population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
# df.rename({"population" : "Population", "country" : "Country"}, axis = 1)

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df_renamed = df.rename({"population" : "Population", "country" : "Country"}, axis = 1)

# %%
df_renamed.head()
# Out:
#        Country  year  Population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.rename({"population" : "Population", "country" : "Country"}, axis = 1, inplace = True)

# %%
df.head()
# Out:
#        Country  year  Population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
#deleting a column

# %%
df.drop("continent", axis = 1)
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.head()
# Out:
#        Country  year  Population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.drop("continent", axis = 1, inplace = True)
#HW - try deleting multiple columns using this syntax

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
#way2 to drop a column

# %%
df_renamed.head()
# Out:
#        Country  year  Population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df_renamed.drop(columns = ["continent"])
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df_renamed.head()
# Out:
#        Country  year  Population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df_renamed.drop(columns = ["continent"], inplace = True)

# %%
df_renamed.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df_renamed.drop(columns = ["Country", "Population"], inplace = True )

# %%
df_renamed.head()
# Out:
#    year  life_exp     gdp_cap
# 0  1952    28.801  779.445314
# 1  1957    30.332  820.853030
# 2  1962    31.997  853.100710
# 3  1967    34.020  836.197138
# 4  1972    36.088  739.981106

# %%
#Creating a new column

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df["year+7"] = df["year"] + 7

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap  year+7
# 0  Afghanistan  1952     8425333    28.801  779.445314    1959
# 1  Afghanistan  1957     9240934    30.332  820.853030    1964
# 2  Afghanistan  1962    10267083    31.997  853.100710    1969
# 3  Afghanistan  1967    11537966    34.020  836.197138    1974
# 4  Afghanistan  1972    13079460    36.088  739.981106    1979

# %%
#GDP = GDP_percapita*population

# %%
df["gdp"] = df["gdp_cap"]*df["Population"]

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap  year+7           gdp
# 0  Afghanistan  1952     8425333    28.801  779.445314    1959  6.567086e+09
# 1  Afghanistan  1957     9240934    30.332  820.853030    1964  7.585449e+09
# 2  Afghanistan  1962    10267083    31.997  853.100710    1969  8.758856e+09
# 3  Afghanistan  1967    11537966    34.020  836.197138    1974  9.648014e+09
# 4  Afghanistan  1972    13079460    36.088  739.981106    1979  9.678553e+09

# %%
df.shape
# Out:
# (1704, 7)

# %%
df["new"] = [i for i in range(1704)]

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap  year+7           gdp  \
# 0  Afghanistan  1952     8425333    28.801  779.445314    1959  6.567086e+09
# 1  Afghanistan  1957     9240934    30.332  820.853030    1964  7.585449e+09
# 2  Afghanistan  1962    10267083    31.997  853.100710    1969  8.758856e+09
# 3  Afghanistan  1967    11537966    34.020  836.197138    1974  9.648014e+09
# 4  Afghanistan  1972    13079460    36.088  739.981106    1979  9.678553e+09
#
#    new
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4

# %%
df.drop(columns = ["year+7", "gdp", "new"], inplace = True)
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
#dataframe indexing

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.columns
# Out:
# Index(['Country', 'year', 'Population', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 1701, 1702, 1703])

# %%
n = df.shape[0]
df.index = [i for i in range(1, n+1)]

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
sample = df.head()

# %%
sample
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
sample.index = ["a", "d" , "c", "b", "f"]
sample.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# a  Afghanistan  1952     8425333    28.801  779.445314
# d  Afghanistan  1957     9240934    30.332  820.853030
# c  Afghanistan  1962    10267083    31.997  853.100710
# b  Afghanistan  1967    11537966    34.020  836.197138
# f  Afghanistan  1972    13079460    36.088  739.981106

# %%
ser = sample["year"]
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser
# Out:
# a    1952
# d    1957
# c    1962
# b    1967
# f    1972
# Name: year, dtype: int64

# %%
ser[2] #implicit
# Out:
# 1962

# %%
ser["c"] #explicit
# Out:
# 1962

# %%
'''
Implicit index --> 0 --> iloc
Explicit index --> visible --> loc
'''
# Out:
# '\nImplicit index --> 0 --> iloc\nExplicit index --> visible --> loc\n'

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.loc[1]
# Out:
# Country       Afghanistan
# year                 1952
# Population        8425333
# life_exp           28.801
# gdp_cap        779.445314
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# Country       Afghanistan
# year                 1957
# Population        9240934
# life_exp           30.332
# gdp_cap         820.85303
# Name: 2, dtype: object

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.loc[1:3] #here in slicing end is inclusive
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710

# %%
df.iloc[1:3] #here in sicing end is exclusive
# Out:
#        Country  year  Population  life_exp    gdp_cap
# 2  Afghanistan  1957     9240934    30.332  820.85303
# 3  Afghanistan  1962    10267083    31.997  853.10071

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.loc[3:5]
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.iloc[3:5]
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.iloc[ [1, 10] ] #accessing multiple rows
# Out:
#         Country  year  Population  life_exp     gdp_cap
# 2   Afghanistan  1957     9240934    30.332  820.853030
# 11  Afghanistan  2002    25268405    42.129  726.734055

# %%
df
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 1     Afghanistan  1952     8425333    28.801  779.445314
# 2     Afghanistan  1957     9240934    30.332  820.853030
# 3     Afghanistan  1962    10267083    31.997  853.100710
# 4     Afghanistan  1967    11537966    34.020  836.197138
# 5     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1700     Zimbabwe  1987     9216418    62.351  706.157306
# 1701     Zimbabwe  1992    10704340    60.377  693.420786
# 1702     Zimbabwe  1997    11404948    46.809  792.449960
# 1703     Zimbabwe  2002    11926563    39.989  672.038623
# 1704     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.loc[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.iloc[-1]
# Out:
# Country         Zimbabwe
# year                2007
# Population      12311143
# life_exp          43.487
# gdp_cap       469.709298
# Name: 1704, dtype: object

# %%
#resume at 10:06

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
temp = df.set_index("Country")
temp
# Out:
#              year  Population  life_exp     gdp_cap
# Country
# Afghanistan  1952     8425333    28.801  779.445314
# Afghanistan  1957     9240934    30.332  820.853030
# Afghanistan  1962    10267083    31.997  853.100710
# Afghanistan  1967    11537966    34.020  836.197138
# Afghanistan  1972    13079460    36.088  739.981106
# ...           ...         ...       ...         ...
# Zimbabwe     1987     9216418    62.351  706.157306
# Zimbabwe     1992    10704340    60.377  693.420786
# Zimbabwe     1997    11404948    46.809  792.449960
# Zimbabwe     2002    11926563    39.989  672.038623
# Zimbabwe     2007    12311143    43.487  469.709298
#
# [1704 rows x 4 columns]

# %%
temp.head()
# Out:
#              year  Population  life_exp     gdp_cap
# Country
# Afghanistan  1952     8425333    28.801  779.445314
# Afghanistan  1957     9240934    30.332  820.853030
# Afghanistan  1962    10267083    31.997  853.100710
# Afghanistan  1967    11537966    34.020  836.197138
# Afghanistan  1972    13079460    36.088  739.981106

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
temp.loc["Afghanistan"]
# Out:
#              year  Population  life_exp     gdp_cap
# Country
# Afghanistan  1952     8425333    28.801  779.445314
# Afghanistan  1957     9240934    30.332  820.853030
# Afghanistan  1962    10267083    31.997  853.100710
# Afghanistan  1967    11537966    34.020  836.197138
# Afghanistan  1972    13079460    36.088  739.981106
# Afghanistan  1977    14880372    38.438  786.113360
# Afghanistan  1982    12881816    39.854  978.011439
# Afghanistan  1987    13867957    40.822  852.395945
# Afghanistan  1992    16317921    41.674  649.341395
# Afghanistan  1997    22227415    41.763  635.341351
# Afghanistan  2002    25268405    42.129  726.734055
# Afghanistan  2007    31889923    43.828  974.580338

# %%
temp.iloc["Afghanistan"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-197-5569527f1d61> in <cell line: 1>()
# ----> 1 temp.iloc["Afghanistan"]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1620             key = item_from_zerodim(key)
#    1621             if not is_integer(key):
# -> 1622                 raise TypeError("Cannot index by location index with a non-integer key")
#    1623
#    1624             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.reset_index()
# Out:
#       index      Country  year  Population  life_exp     gdp_cap
# 0         1  Afghanistan  1952     8425333    28.801  779.445314
# 1         2  Afghanistan  1957     9240934    30.332  820.853030
# 2         3  Afghanistan  1962    10267083    31.997  853.100710
# 3         4  Afghanistan  1967    11537966    34.020  836.197138
# 4         5  Afghanistan  1972    13079460    36.088  739.981106
# ...     ...          ...   ...         ...       ...         ...
# 1699   1700     Zimbabwe  1987     9216418    62.351  706.157306
# 1700   1701     Zimbabwe  1992    10704340    60.377  693.420786
# 1701   1702     Zimbabwe  1997    11404948    46.809  792.449960
# 1702   1703     Zimbabwe  2002    11926563    39.989  672.038623
# 1703   1704     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.reset_index(drop = True)
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 3     Afghanistan  1967    11537966    34.020  836.197138
# 4     Afghanistan  1972    13079460    36.088  739.981106
# ...           ...   ...         ...       ...         ...
# 1699     Zimbabwe  1987     9216418    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
#
# [1704 rows x 5 columns]

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1952     8425333    28.801  779.445314
# 2  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1962    10267083    31.997  853.100710
# 4  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.reset_index(drop = True, inplace = True)

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df_sample = df.head()

# %%
df_sample
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df_sample.drop(columns = ["year"])
# Out:
#        Country  Population  life_exp     gdp_cap
# 0  Afghanistan     8425333    28.801  779.445314
# 1  Afghanistan     9240934    30.332  820.853030
# 2  Afghanistan    10267083    31.997  853.100710
# 3  Afghanistan    11537966    34.020  836.197138
# 4  Afghanistan    13079460    36.088  739.981106

# %%
df_sample
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df_sample = df_sample.drop(columns = ["year"])

# %%
df_sample.head()
# Out:
#        Country  Population  life_exp     gdp_cap
# 0  Afghanistan     8425333    28.801  779.445314
# 1  Afghanistan     9240934    30.332  820.853030
# 2  Afghanistan    10267083    31.997  853.100710
# 3  Afghanistan    11537966    34.020  836.197138
# 4  Afghanistan    13079460    36.088  739.981106

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   Population  1704 non-null   int64
#  3   life_exp    1704 non-null   float64
#  4   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 66.7+ KB

# %%
df.head(10)
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106
# 5  Afghanistan  1977    14880372    38.438  786.113360
# 6  Afghanistan  1982    12881816    39.854  978.011439
# 7  Afghanistan  1987    13867957    40.822  852.395945
# 8  Afghanistan  1992    16317921    41.674  649.341395
# 9  Afghanistan  1997    22227415    41.763  635.341351

# %%
df.iloc[1:5 , 1:4]
# Out:
#    year  Population  life_exp
# 1  1957     9240934    30.332
# 2  1962    10267083    31.997
# 3  1967    11537966    34.020
# 4  1972    13079460    36.088

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.loc[1:5, 1:4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-214-494208dc7680> in <cell line: 1>()
# ----> 1 df.loc[1:5, 1:4]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1254             return self._multi_take(tup)
#    1255
# -> 1256         return self._getitem_tuple_same_dim(tup)
#    1257
#    1258     def _get_label(self, label, axis: int):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
# ...

# %%
df.loc[1:5 , ["Country", "life_exp"]]
# Out:
#        Country  life_exp
# 1  Afghanistan    30.332
# 2  Afghanistan    31.997
# 3  Afghanistan    34.020
# 4  Afghanistan    36.088
# 5  Afghanistan    38.438

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.loc[1:5, "Country":"life_exp"]
# Out:
#        Country  year  Population  life_exp
# 1  Afghanistan  1957     9240934    30.332
# 2  Afghanistan  1962    10267083    31.997
# 3  Afghanistan  1967    11537966    34.020
# 4  Afghanistan  1972    13079460    36.088
# 5  Afghanistan  1977    14880372    38.438

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.iloc[ [0,10,20] , [0,2,3]]
# Out:
#         Country  Population  life_exp
# 0   Afghanistan     8425333    28.801
# 10  Afghanistan    25268405    42.129
# 20      Albania     3326498    71.581

# %%
df.iloc[1:10:2]
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1977    14880372    38.438  786.113360
# 7  Afghanistan  1987    13867957    40.822  852.395945
# 9  Afghanistan  1997    22227415    41.763  635.341351

# %%
df.head(15)
# Out:
#         Country  year  Population  life_exp      gdp_cap
# 0   Afghanistan  1952     8425333    28.801   779.445314
# 1   Afghanistan  1957     9240934    30.332   820.853030
# 2   Afghanistan  1962    10267083    31.997   853.100710
# 3   Afghanistan  1967    11537966    34.020   836.197138
# 4   Afghanistan  1972    13079460    36.088   739.981106
# 5   Afghanistan  1977    14880372    38.438   786.113360
# 6   Afghanistan  1982    12881816    39.854   978.011439
# 7   Afghanistan  1987    13867957    40.822   852.395945
# 8   Afghanistan  1992    16317921    41.674   649.341395
# 9   Afghanistan  1997    22227415    41.763   635.341351
# 10  Afghanistan  2002    25268405    42.129   726.734055
# 11  Afghanistan  2007    31889923    43.828   974.580338
# 12      Albania  1952     1282697    55.230  1601.056136
# 13      Albania  1957     1476505    59.280  1942.284244
# 14      Albania  1962     1728137    64.820  2312.888958

# %%
df.loc[1:11:2]
# Out:
#         Country  year  Population  life_exp     gdp_cap
# 1   Afghanistan  1957     9240934    30.332  820.853030
# 3   Afghanistan  1967    11537966    34.020  836.197138
# 5   Afghanistan  1977    14880372    38.438  786.113360
# 7   Afghanistan  1987    13867957    40.822  852.395945
# 9   Afghanistan  1997    22227415    41.763  635.341351
# 11  Afghanistan  2007    31889923    43.828  974.580338

# %%
df.iloc[1:11:2]
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 5  Afghanistan  1977    14880372    38.438  786.113360
# 7  Afghanistan  1987    13867957    40.822  852.395945
# 9  Afghanistan  1997    22227415    41.763  635.341351

# %%
df.tail()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1699  Zimbabwe  1987     9216418    62.351  706.157306
# 1700  Zimbabwe  1992    10704340    60.377  693.420786
# 1701  Zimbabwe  1997    11404948    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    43.487  469.709298

# %%
new_row = {'Country':'India', 'year':2000, 'Population':13500000, 'continent':'Asia', 'life_exp':37.08,  'gdp_cap':900.23}

# %%
df.append(new_row)
# Out:
# <ipython-input-226-98696000c65c>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(new_row)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-226-98696000c65c> in <cell line: 1>()
# ----> 1 df.append(new_row)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    9766         )
#    9767
# -> 9768         return self._append(other, ignore_index, verify_integrity, sort)
#    9769
#    9770     def _append(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _append(self, other, ignore_index, verify_integrity, sort)
#    9778             if isinstance(other, dict):
#    9779                 if not ignore_index:
# ...

# %%
df = df.append(new_row, ignore_index=True)
# Out:
# <ipython-input-227-caa379dde9af>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)

# %%
df.tail()
# Out:
#        Country  year  Population  life_exp     gdp_cap continent
# 1700  Zimbabwe  1992    10704340    60.377  693.420786       NaN
# 1701  Zimbabwe  1997    11404948    46.809  792.449960       NaN
# 1702  Zimbabwe  2002    11926563    39.989  672.038623       NaN
# 1703  Zimbabwe  2007    12311143    43.487  469.709298       NaN
# 1704     India  2000    13500000    37.080  900.230000      Asia

# %%
df.drop(columns = ["continent"], inplace = True)

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.iloc[len(df.index)] = ['India', 1900, 13500000 , 37.08, 900.23]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-231-a82ba92d97f5> in <cell line: 1>()
# ----> 1 df.iloc[len(df.index)] = ['India', 1900, 13500000 , 37.08, 900.23]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     813             key = com.apply_if_callable(key, self.obj)
#     814         indexer = self._get_setitem_indexer(key)
# --> 815         self._has_valid_setitem_indexer(key)
#     816
#     817         iloc = self if self.name == "iloc" else self.obj.iloc
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _has_valid_setitem_indexer(self, indexer)
#    1516             elif is_integer(i):
#    1517                 if i >= len(ax):
# -> 1518                     raise IndexError("iloc cannot enlarge its target object")
#    1519             elif isinstance(i, dict):
# ...

# %%
df.loc[len(df.index)] = ['India', 1900, 13500000 , 37.08, 900.23]

# %%
df.tail()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1701  Zimbabwe  1997    11404948    46.809  792.449960
# 1702  Zimbabwe  2002    11926563    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    43.487  469.709298
# 1704     India  2000    13500000    37.080  900.230000
# 1705     India  1900    13500000    37.080  900.230000

# %%
df.loc[len(df.index)] = ['India', 2023, 13500000 , 37.08, 900.23]

# %%
df.tail()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1702  Zimbabwe  2002    11926563    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    43.487  469.709298
# 1704     India  2000    13500000    37.080  900.230000
# 1705     India  1900    13500000    37.080  900.230000
# 1706     India  2023    13500000    37.080  900.230000

# %%
df.loc[1706] = ['India', 2025, 13500000 , 37.08, 900.23] #modifying an existing row

# %%
df.tail()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1702  Zimbabwe  2002    11926563    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    43.487  469.709298
# 1704     India  2000    13500000    37.080  900.230000
# 1705     India  1900    13500000    37.080  900.230000
# 1706     India  2025    13500000    37.080  900.230000

# %%
df.drop("Country", axis = 1) #deleint the Country column
# Out:
#       year  Population  life_exp     gdp_cap
# 0     1952     8425333    28.801  779.445314
# 1     1957     9240934    30.332  820.853030
# 2     1962    10267083    31.997  853.100710
# 3     1967    11537966    34.020  836.197138
# 4     1972    13079460    36.088  739.981106
# ...    ...         ...       ...         ...
# 1702  2002    11926563    39.989  672.038623
# 1703  2007    12311143    43.487  469.709298
# 1704  2000    13500000    37.080  900.230000
# 1705  1900    13500000    37.080  900.230000
# 1706  2025    13500000    37.080  900.230000
#
# [1707 rows x 4 columns]

# %%
df.drop(3, axis = 0) #deleint the row
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 4     Afghanistan  1972    13079460    36.088  739.981106
# 5     Afghanistan  1977    14880372    38.438  786.113360
# ...           ...   ...         ...       ...         ...
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
# 1704        India  2000    13500000    37.080  900.230000
# 1705        India  1900    13500000    37.080  900.230000
# 1706        India  2025    13500000    37.080  900.230000
#
# [1706 rows x 5 columns]

# %%
df.drop([3,5,10], axis = 0) #deleint the row
# Out:
#           Country  year  Population  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333    28.801  779.445314
# 1     Afghanistan  1957     9240934    30.332  820.853030
# 2     Afghanistan  1962    10267083    31.997  853.100710
# 4     Afghanistan  1972    13079460    36.088  739.981106
# 6     Afghanistan  1982    12881816    39.854  978.011439
# ...           ...   ...         ...       ...         ...
# 1702     Zimbabwe  2002    11926563    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    43.487  469.709298
# 1704        India  2000    13500000    37.080  900.230000
# 1705        India  1900    13500000    37.080  900.230000
# 1706        India  2025    13500000    37.080  900.230000
#
# [1704 rows x 5 columns]

# %%
df.reset_index(drop = True, inplace = True)

# %%
df.head()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333    28.801  779.445314
# 1  Afghanistan  1957     9240934    30.332  820.853030
# 2  Afghanistan  1962    10267083    31.997  853.100710
# 3  Afghanistan  1967    11537966    34.020  836.197138
# 4  Afghanistan  1972    13079460    36.088  739.981106

# %%
df.tail()
# Out:
#        Country  year  Population  life_exp     gdp_cap
# 1702  Zimbabwe  2002    11926563    39.989  672.038623
# 1703  Zimbabwe  2007    12311143    43.487  469.709298
# 1704     India  2000    13500000    37.080  900.230000
# 1705     India  1900    13500000    37.080  900.230000
# 1706     India  2025    13500000    37.080  900.230000

# %%
df.loc[len(df.index)] = ['India',2000,13500000,37.08,900.23]
df.loc[len(df.index)] = ['India',2000,13500000,37.08,900.23]

# %%
df.tail()
# Out:
#      Country  year  Population  life_exp  gdp_cap
# 1704   India  2000    13500000     37.08   900.23
# 1705   India  1900    13500000     37.08   900.23
# 1706   India  2025    13500000     37.08   900.23
# 1707   India  2000    13500000     37.08   900.23
# 1708   India  2000    13500000     37.08   900.23

# %%
#Duplicate rows
# Sorting and variants
