# %% [markdown]
# <a href="https://colab.research.google.com/github/adityajain2407/DAV-1-may23/blob/main/may23_pandas_3a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget "https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_" -O mckinsey.csv
# Out:
# --2023-09-11 15:39:10--  https://drive.google.com/uc?export=download&id=1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_
# Resolving drive.google.com (drive.google.com)... 173.194.74.100, 173.194.74.102, 173.194.74.139, ...
# Connecting to drive.google.com (drive.google.com)|173.194.74.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/745s4dosnos0imtj7io82t7kgiijhg9b/1694446725000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?e=download&uuid=594e7418-b28b-4dce-a6ea-e4f6677c5703 [following]
# Warning: wildcards not supported in HTTP.
# --2023-09-11 15:39:10--  https://doc-0s-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/745s4dosnos0imtj7io82t7kgiijhg9b/1694446725000/14302370361230157278/*/1E3bwvYGf1ig32RmcYiWc0IXPN-mD_bI_?e=download&uuid=594e7418-b28b-4dce-a6ea-e4f6677c5703
# Resolving doc-0s-68-docs.googleusercontent.com (doc-0s-68-docs.googleusercontent.com)... 74.125.132.132, 2607:f8b0:4001:c00::84
# Connecting to doc-0s-68-docs.googleusercontent.com (doc-0s-68-docs.googleusercontent.com)|74.125.132.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83785 (82K) [text/csv]
# Saving to: ‘mckinsey.csv’
#
# mckinsey.csv        100%[===================>]  81.82K  --.-KB/s    in 0.001s
#
# 2023-09-11 15:39:11 (71.7 MB/s) - ‘mckinsey.csv’ saved [83785/83785]

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("mckinsey.csv")

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.loc[len(df.index)] = ['India',2000,13500000,"asia",37.08,900.23]
df.loc[len(df.index)] = ['Sri Lanka',2022,130000000,"asia",80.00,500.00]
df.loc[len(df.index)] = ['Sri Lanka',2022,130000000,"asia",80.00,500.00]
df.loc[len(df.index)] = ['India',2000,13500000,"asia",80.00,900.23]
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      asia    37.080  900.230000
# 1705    Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1706    Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1707        India  2000    13500000      asia    80.000  900.230000
#
# [1708 rows x 6 columns]

# %%
#Rows --> records
#Columns --> feature, attributes

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1703    False
# 1704    False
# 1705    False
# 1706     True
# 1707    False
# Length: 1708, dtype: bool

# %%
df_dup = df.loc[df.duplicated()] #storing all the duplicate rows

# %%
df_dup.head()
# Out:
#         country  year  population continent  life_exp  gdp_cap
# 1706  Sri Lanka  2022   130000000      asia      80.0    500.0

# %%
df.drop_duplicates()
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      asia    37.080  900.230000
# 1705    Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1707        India  2000    13500000      asia    80.000  900.230000
#
# [1707 rows x 6 columns]

# %%
df.tail()
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 1703   Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704      India  2000    13500000      asia    37.080  900.230000
# 1705  Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1706  Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1707      India  2000    13500000      asia    80.000  900.230000

# %%
df.drop_duplicates(keep = "first")
#keeps the first occurance of a record and deletes the rest
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      asia    37.080  900.230000
# 1705    Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1707        India  2000    13500000      asia    80.000  900.230000
#
# [1707 rows x 6 columns]

# %%
df.drop_duplicates(keep = "last")
#keeps the last occurance of a record and deletes the rest
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704        India  2000    13500000      asia    37.080  900.230000
# 1706    Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1707        India  2000    13500000      asia    80.000  900.230000
#
# [1707 rows x 6 columns]

# %%
df.tail()
# Out:
#         country  year  population continent  life_exp     gdp_cap
# 1703   Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1704      India  2000    13500000      asia    37.080  900.230000
# 1705  Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1706  Sri Lanka  2022   130000000      asia    80.000  500.000000
# 1707      India  2000    13500000      asia    80.000  900.230000

# %%
life_ex = df["life_exp"]
print(life_ex)
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1703    43.487
# 1704    37.080
# 1705    80.000
# 1706    80.000
# 1707    80.000
# Name: life_exp, Length: 1708, dtype: float64

# %%
life_ex.mean()
# Out:
# 59.49737978922717

# %%
sum_le = life_ex.sum()

# %%
print(sum_le)
# Out:
# 101621.52468

# %%
count_le = life_ex.count()
print(count_le)
# Out:
# 1708

# %%
sum_le/count_le
# Out:
# 59.49737978922717

# %%
df.head()
# Out:
#        country  year  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.sort_values(["life_exp"]) #by default: ascending = True
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 1292            Rwanda  1992     7290203    Africa    23.599    737.068595
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 36              Angola  1952     4232095    Africa    30.015   3520.610273
# 1344      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# ...                ...   ...         ...       ...       ...           ...
# 1487       Switzerland  2007     7554661    Europe    81.701  37506.419070
# 695            Iceland  2007      301931    Europe    81.757  36180.789190
# 802              Japan  2002   127065841      Asia    82.000  28604.591900
# 671   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 803              Japan  2007   127467972      Asia    82.603  31656.068060
#
# [1708 rows x 6 columns]

# %%
df.sort_values(["life_exp"], ascending = False ) #descending order
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 803              Japan  2007   127467972      Asia    82.603  31656.068060
# 671   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 802              Japan  2002   127065841      Asia    82.000  28604.591900
# 695            Iceland  2007      301931    Europe    81.757  36180.789190
# 1487       Switzerland  2007     7554661    Europe    81.701  37506.419070
# ...                ...   ...         ...       ...       ...           ...
# 1344      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# 36              Angola  1952     4232095    Africa    30.015   3520.610273
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 1292            Rwanda  1992     7290203    Africa    23.599    737.068595
#
# [1708 rows x 6 columns]

# %%
df.sort_values(["year", "life_exp"]) #behaviour same as sql
# Out:
#                country  year  population continent  life_exp       gdp_cap
# 0          Afghanistan  1952     8425333      Asia    28.801    779.445314
# 552             Gambia  1952      284320    Africa    30.000    485.230659
# 36              Angola  1952     4232095    Africa    30.015   3520.610273
# 1344      Sierra Leone  1952     2143249    Africa    30.331    879.787736
# 1032        Mozambique  1952     6446316    Africa    31.286    468.526038
# ...                ...   ...         ...       ...       ...           ...
# 695            Iceland  2007      301931    Europe    81.757  36180.789190
# 671   Hong Kong, China  2007     6980412      Asia    82.208  39724.978670
# 803              Japan  2007   127467972      Asia    82.603  31656.068060
# 1705         Sri Lanka  2022   130000000      asia    80.000    500.000000
# 1706         Sri Lanka  2022   130000000      asia    80.000    500.000000
#
# [1708 rows x 6 columns]

# %%
df.sort_values(["year", "life_exp"], ascending = [True, False])
# Out:
#           country  year  population continent  life_exp       gdp_cap
# 1140       Norway  1952     3327728    Europe    72.670  10095.421720
# 684       Iceland  1952      147962    Europe    72.490   7267.688428
# 1080  Netherlands  1952    10381988    Europe    72.130   8941.571858
# 1464       Sweden  1952     7124673    Europe    71.860   8527.844662
# 408       Denmark  1952     4334000    Europe    70.780   9692.385245
# ...           ...   ...         ...       ...       ...           ...
# 1691       Zambia  2007    11746035    Africa    42.384   1271.211593
# 1043   Mozambique  2007    19951656    Africa    42.082    823.685621
# 1463    Swaziland  2007     1133066    Africa    39.613   4513.480643
# 1705    Sri Lanka  2022   130000000      asia    80.000    500.000000
# 1706    Sri Lanka  2022   130000000      asia    80.000    500.000000
#
# [1708 rows x 6 columns]

# %%
users = pd.DataFrame({"userid":[1, 2, 3], "name":["Deepak", "Kunal", "Sangram"]})
users
# Out:
#    userid     name
# 0       1   Deepak
# 1       2    Kunal
# 2       3  Sangram

# %%
msgs = pd.DataFrame({"userid":[1, 1, 2, 4], "msg":['hmm', "acha", "theek hai", "nice"]})
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1       acha
# 2       2  theek hai
# 3       4       nice

# %%
pd.concat([users, msgs], axis = 0)
# Out:
#    userid     name        msg
# 0       1   Deepak        NaN
# 1       2    Kunal        NaN
# 2       3  Sangram        NaN
# 0       1      NaN        hmm
# 1       1      NaN       acha
# 2       2      NaN  theek hai
# 3       4      NaN       nice

# %%
pd.concat([users, msgs], axis = 0, ignore_index = True)
# Out:
#    userid     name        msg
# 0       1   Deepak        NaN
# 1       2    Kunal        NaN
# 2       3  Sangram        NaN
# 3       1      NaN        hmm
# 4       1      NaN       acha
# 5       2      NaN  theek hai
# 6       4      NaN       nice

# %%
pd.concat([users, msgs], axis = 1)
# Out:
#    userid     name  userid        msg
# 0     1.0   Deepak       1        hmm
# 1     2.0    Kunal       1       acha
# 2     3.0  Sangram       2  theek hai
# 3     NaN      NaN       4       nice

# %%
#joins --> merge

# %%
users
# Out:
#    userid     name
# 0       1   Deepak
# 1       2    Kunal
# 2       3  Sangram

# %%
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1       acha
# 2       2  theek hai
# 3       4       nice

# %%
users.merge(msgs, on = "userid") #inner join
# Out:
#    userid    name        msg
# 0       1  Deepak        hmm
# 1       1  Deepak       acha
# 2       2   Kunal  theek hai

# %%
users.merge(msgs, on = "userid", how = "left")
# Out:
#    userid     name        msg
# 0       1   Deepak        hmm
# 1       1   Deepak       acha
# 2       2    Kunal  theek hai
# 3       3  Sangram        NaN

# %%
#explore: right, outer, inner, etc

# %%
users.rename(columns = {"userid" : "id"}, inplace = True)

# %%
users
# Out:
#    id     name
# 0   1   Deepak
# 1   2    Kunal
# 2   3  Sangram

# %%
msgs
# Out:
#    userid        msg
# 0       1        hmm
# 1       1       acha
# 2       2  theek hai
# 3       4       nice

# %%
users.merge(msgs, left_on = "id", right_on = "userid")
# Out:
#    id    name  userid        msg
# 0   1  Deepak       1        hmm
# 1   1  Deepak       1       acha
# 2   2   Kunal       2  theek hai

# %%
users.merge(msgs, left_on = "id", right_on = "userid", how = "left")
# Out:
#    id     name  userid        msg
# 0   1   Deepak     1.0        hmm
# 1   1   Deepak     1.0       acha
# 2   2    Kunal     2.0  theek hai
# 3   3  Sangram     NaN        NaN
